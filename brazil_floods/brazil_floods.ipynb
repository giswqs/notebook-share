# %% [markdown]
# [![Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/giswqs/notebook-share/blob/master/docs/brazil_floods.ipynb)
# [![Open in SageMaker Studio Lab](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github/giswqs/notebook-share/blob/master/docs/brazil_floods.ipynb)
# [![Open in Planetary Computer](https://img.shields.io/badge/Open-Planetary%20Computer-black?style=flat&logo=microsoft)](https://pccompute.westeurope.cloudapp.azure.com/compute/hub/user-redirect/git-pull?repo=https://github.com/giswqs/notebook-share&urlpath=lab/tree/notebook-share/docs/brazil_floods.ipynb&branch=master)
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/giswqs/notebook-share/HEAD?labpath=docs%brazil_floods.ipynb)

# %% [markdown]
# # Visualization and Analysis of Brazil Floods 2024

# %% [markdown]
# ## Introduction
#
# The 2024 Rio Grande do Sul floods are severe floods caused by heavy rains and storms that have hit the Brazilian state of Rio Grande do Sul, and the adjacent Uruguayan cities of Treinta y Tres, Paysandú, Cerro Largo, and Salto. From 29 April 2024 through to May 2024, it resulted in over 140 fatalities, widespread landslides, and a dam collapse. It is considered the country's worst flooding in over 80 years. See the [Wikipedia](https://en.wikipedia.org/wiki/2024_Rio_Grande_do_Sul_floods) page for more information about the 2024 Brazil floods.
#
#
# ## Requirements
#
# To follow this tutorial, you must first [sign up](https://earthengine.google.com/signup) for a [Google Earth Engine](https://earthengine.google.com/) account. Earth Engine is a cloud computing platform with a [multi-petabyte catalog](https://developers.google.com/earth-engine/datasets/) of satellite imagery and geospatial datasets. It is free for noncommercial use. To authenticate the Earth Engine Python API, see instructions [here](https://book.geemap.org/chapters/01_introduction.html#earth-engine-authentication).
#
# In this tutorial, we will use the [geemap](https://geemap.org) Python package to visualize and analyze the Pakistan floods. Geemap enables users to analyze and visualize Earth Engine datasets interactively within a Jupyter-based environment with minimal coding. To learn more about geemap, check out https://geemap.org.

# %% [markdown]
# ## Installation
#
# Uncomment the following line to install geemap if needed.

# %%
# !pip install geemap

# %% [markdown]
# ## Import libraries
#
# Import the earthengine-api and geemap.

# %%
import ee
import geemap.foliumap as geemap

# %%
geemap.ee_initialize()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Download administrative boundaries
#
# Download the administrative boundaries of Rio Grande doSul, Brazil from [here](https://github.com/opengeos/datasets/releases/tag/places).

# %%
url = "https://github.com/opengeos/datasets/releases/download/places/Rio_Grande_do_Sul_Brazil.geojson"
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
roi = geemap.geojson_to_ee(url)
# roi
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Downloading...
# From: https://github.com/opengeos/datasets/releases/download/places/Rio_Grande_do_Sul_Brazil.geojson
# To: /tmp/f9545ed0-d76c-477a-ba1c-5c3a154dae24.geojson
# 100%|███████████████████████████████████████████████████████| 61.2k/61.2k [00:00<00:00, 2.12MB/s]

# %%
centroid = roi.geometry().centroid(1)
lon, lat = centroid.getInfo()["coordinates"]
print(f"Longitude: {lon}, Latitude: {lat}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Longitude: -53.2453436538024, Latitude: -29.778651228599525

# %% [markdown]
# ## Create an interactive map
#
# Specify the center point `[lat, lon]` and zoom level of the map.

# %%
Map = geemap.Map()
style = {"fillColor": "00000000", "color": "FF0000"}
Map.addLayer(roi.style(**style), {}, "ROI")
geom = roi.geometry()
Map.centerObject(geom, 6)
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bc5c02759e342057bbb56c4df6de3002 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bc5c02759e342057bbb56c4df6de3002&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bc5c02759e342057bbb56c4df6de3002 = L.map(
#                 &quot;map_bc5c02759e342057bbb56c4df6de3002&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: false,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f7c1f8ddd9a2e07b1c122b053b79d46e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f7c1f8ddd9a2e07b1c122b053b79d46e.addTo(map_bc5c02759e342057bbb56c4df6de3002);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_bc5c02759e342057bbb56c4df6de3002);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_25e5dcdc783530410a1bc96498a85726 = new L.featureGroup().addTo(
#                 map_bc5c02759e342057bbb56c4df6de3002
#             );
#             options.edit.featureGroup = drawnItems_draw_control_25e5dcdc783530410a1bc96498a85726;
#             var draw_control_25e5dcdc783530410a1bc96498a85726 = new L.Control.Draw(
#                 options
#             ).addTo( map_bc5c02759e342057bbb56c4df6de3002 );
#             map_bc5c02759e342057bbb56c4df6de3002.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_25e5dcdc783530410a1bc96498a85726.addLayer(layer);
#              });
#             map_bc5c02759e342057bbb56c4df6de3002.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_25e5dcdc783530410a1bc96498a85726.addLayer(e.layer);
#             });
#
#
#
#
#             var geocoderOpts_geocoder_d8452a3b4351c54e03db1f956cc41aa3 = {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_d8452a3b4351c54e03db1f956cc41aa3 = geocoderOpts_geocoder_d8452a3b4351c54e03db1f956cc41aa3[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_d8452a3b4351c54e03db1f956cc41aa3 = L.Control.Geocoder[ geocoderName_geocoder_d8452a3b4351c54e03db1f956cc41aa3 ](
#                 geocoderOpts_geocoder_d8452a3b4351c54e03db1f956cc41aa3[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_d8452a3b4351c54e03db1f956cc41aa3[&quot;geocoder&quot;] = customGeocoder_geocoder_d8452a3b4351c54e03db1f956cc41aa3;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_d8452a3b4351c54e03db1f956cc41aa3
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_d8452a3b4351c54e03db1f956cc41aa3[&#x27;zoom&#x27;] || map_bc5c02759e342057bbb56c4df6de3002.getZoom();
#                 map_bc5c02759e342057bbb56c4df6de3002.setView(e.geocode.center, zoom);
#             }).addTo(map_bc5c02759e342057bbb56c4df6de3002);
#
#
#
#             map_bc5c02759e342057bbb56c4df6de3002.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&

# %% [markdown]
# In the tutorial, we will focus on  Rio Grande do Sul in Brazil, but the code can be easily modified to visualize and analyze floods in other countries. Modify the `place_name` variable to specify the place of interest and set the date range for the flood event. In order to extract the flood extent, we also need to specify the date range for the pre-flood period.

# %%
place_name = "Rio Grande do Sul"
pre_flood_start_date = "2024-01-01"
pre_flood_end_date = "2024-04-27"
post_flood_start_date = "2024-04-29"
post_flood_end_date = "2024-05-17"
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Create Landsat composites
#
# Create a Landsat 8 composite for the pre-flood period (August 1 to September 30, 2021) using the [USGS Landsat 8 Collection 2 Tier 1 Raw Scenes](https://developers.google.com/earth-engine/datasets/catalog/LANDSAT_LC08_C02_T1).

# %%
pre_flood_col = (
    ee.ImageCollection("NASA/HLS/HLSL30/v002")
    .filterBounds(roi)
    .filterDate(pre_flood_start_date, pre_flood_end_date)
    .filter(ee.Filter.lt("CLOUD_COVERAGE", 15))
)
print(
    f"The number of images in the pre-flood collection: {pre_flood_col.size().getInfo()}"
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# The number of images in the pre-flood collection: 374

# %%
post_flood_col = (
    ee.ImageCollection("NASA/HLS/HLSL30/v002")
    .filterBounds(roi)
    .filterDate(post_flood_start_date, post_flood_end_date)
    .filter(ee.Filter.lt("CLOUD_COVERAGE", 50))
)
print(
    f"The number of images in the post-flood collection: {post_flood_col.size().getInfo()}"
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# The number of images in the post-flood collection: 34

# %% [markdown]
# Visualize the Landsat 8 composite for the pre-flood and flood periods.

# %%
Map = geemap.Map()

pre_flood_image = pre_flood_col.median().clipToCollection(roi)
post_flood_image = post_flood_col.median().clipToCollection(roi)

vis_params = {"bands": ["B6", "B5", "B4"], "min": 0, "max": 0.4}
Map.addLayer(pre_flood_image, vis_params, "Landsat Pre-flood")
Map.addLayer(post_flood_image, vis_params, "Landsat Post-flood")
Map.addLayer(roi.style(**style), {}, place_name)
Map.centerObject(roi, 6)
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e3988a4f99833e340b1bf4e8906cb1e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e3988a4f99833e340b1bf4e8906cb1e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e3988a4f99833e340b1bf4e8906cb1e = L.map(
#                 &quot;map_7e3988a4f99833e340b1bf4e8906cb1e&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: false,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_af0c6f927a0519e402350f86a22371d9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_af0c6f927a0519e402350f86a22371d9.addTo(map_7e3988a4f99833e340b1bf4e8906cb1e);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_7e3988a4f99833e340b1bf4e8906cb1e);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_0d45ca59e7d1284408a1659a8f2e8f91 = new L.featureGroup().addTo(
#                 map_7e3988a4f99833e340b1bf4e8906cb1e
#             );
#             options.edit.featureGroup = drawnItems_draw_control_0d45ca59e7d1284408a1659a8f2e8f91;
#             var draw_control_0d45ca59e7d1284408a1659a8f2e8f91 = new L.Control.Draw(
#                 options
#             ).addTo( map_7e3988a4f99833e340b1bf4e8906cb1e );
#             map_7e3988a4f99833e340b1bf4e8906cb1e.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_0d45ca59e7d1284408a1659a8f2e8f91.addLayer(layer);
#              });
#             map_7e3988a4f99833e340b1bf4e8906cb1e.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_0d45ca59e7d1284408a1659a8f2e8f91.addLayer(e.layer);
#             });
#
#
#
#
#             var geocoderOpts_geocoder_4cecaa0cd606a455adca39dbcb26842d = {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_4cecaa0cd606a455adca39dbcb26842d = geocoderOpts_geocoder_4cecaa0cd606a455adca39dbcb26842d[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_4cecaa0cd606a455adca39dbcb26842d = L.Control.Geocoder[ geocoderName_geocoder_4cecaa0cd606a455adca39dbcb26842d ](
#                 geocoderOpts_geocoder_4cecaa0cd606a455adca39dbcb26842d[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_4cecaa0cd606a455adca39dbcb26842d[&quot;geocoder&quot;] = customGeocoder_geocoder_4cecaa0cd606a455adca39dbcb26842d;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_4cecaa0cd606a455adca39dbcb26842d
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_4cecaa0cd606a455adca39dbcb26842d[&#x27;zoom&#x27;] || map_7e3988a4f99833e340b1bf4e8906cb1e.getZoom();
#                 map_7e3988a4f99833e340b1bf4e8906cb1e.setView(e.geocode.center, zoom);
#             }).addTo(map_7e3988a4f99833e340b1bf4e8906cb1e);
#
#
#
#             map_7e3988a4f99833e340b1bf4e8906cb1e.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&

# %% [markdown]
# ## Compare Landsat composites side by side
#
# Compare the pre-flood and flood composites side by side.

# %%
Map = geemap.Map()
left_layer = geemap.ee_tile_layer(pre_flood_image, vis_params, "Landsat Pre-flood")
right_layer = geemap.ee_tile_layer(post_flood_image, vis_params, "Landsat Post-flood")
Map.split_map(
    left_layer,
    right_layer,
    left_label="Landsat Pre-flood",
    right_label="Landsat Post-flood",
)
Map.addLayer(roi.style(**style), {}, place_name)
Map.centerObject(roi, 6)
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eb58061cc58cda3a923c41887a376877 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/digidem/leaflet-side-by-side@gh-pages/leaflet-side-by-side.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eb58061cc58cda3a923c41887a376877&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eb58061cc58cda3a923c41887a376877 = L.map(
#                 &quot;map_eb58061cc58cda3a923c41887a376877&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: false,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fe5b1b097b8ec90f6f77c85f4855797e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fe5b1b097b8ec90f6f77c85f4855797e.addTo(map_eb58061cc58cda3a923c41887a376877);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_eb58061cc58cda3a923c41887a376877);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_a5ccdb709cab261e220c5e5f2964c142 = new L.featureGroup().addTo(
#                 map_eb58061cc58cda3a923c41887a376877
#             );
#             options.edit.featureGroup = drawnItems_draw_control_a5ccdb709cab261e220c5e5f2964c142;
#             var draw_control_a5ccdb709cab261e220c5e5f2964c142 = new L.Control.Draw(
#                 options
#             ).addTo( map_eb58061cc58cda3a923c41887a376877 );
#             map_eb58061cc58cda3a923c41887a376877.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_a5ccdb709cab261e220c5e5f2964c142.addLayer(layer);
#              });
#             map_eb58061cc58cda3a923c41887a376877.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_a5ccdb709cab261e220c5e5f2964c142.addLayer(e.layer);
#             });
#
#
#
#
#             var geocoderOpts_geocoder_44a427bbbdcf395131b22636236437e6 = {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_44a427bbbdcf395131b22636236437e6 = geocoderOpts_geocoder_44a427bbbdcf395131b22636236437e6[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_44a427bbbdcf395131b22636236437e6 = L.Control.Geocoder[ geocoderName_geocoder_44a427bbbdcf395131b22636236437e6 ](
#                 geocoderOpts_geocoder_44a427bbbdcf395131b22636236437e6[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_44a427bbbdcf395131b22636236437e6[&quot;geocoder&quot;] = customGeocoder_geocoder_44a427bbbdcf395131b22636236437e6;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_44a427bbbdcf395131b22636236437e6
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_44a427bbbdcf395131b22636236437e6[&#x27;zoom&#x27;] || map_eb58061cc58cda3a923c41887a376877.getZoom();
#                 map_eb58061cc58cda3a923c41887a376877.setView(e.geocode.center, zoom);
#             }).addTo(map_eb58061cc58cda3a923c

# %% [markdown]
# ## Compute Normalized Difference Water Index (NDWI)
#
# The [Normalized Difference Water Index](https://en.wikipedia.org/wiki/Normalized_difference_water_index) (NDWI) is a commonly used index for detecting water bodies. It is calculated as follows:
#
# $$NDWI = \frac{Green - NIR}{Green + NIR}$$
#
# where Green is the green band and NIR is the near-infrared band. The NDWI values range from -1 to 1. The NDWI values are usually thresholded to a positive number (e.g., 0.1-0.3) to identify water bodies.
#
# Landsat 8 imagery has [11 spectral bands](https://developers.google.com/earth-engine/datasets/catalog/LANDSAT_LC08_C02_T1#bands). The Landsat 8 NDWI is calculated using the green (`B3`) and NIR (`B5`) bands.
#
# ![](https://i.imgur.com/yuZthc6.png)

# %%
ndwi_pre = pre_flood_image.normalizedDifference(["B3", "B5"]).rename("NDWI")
ndwi_post = post_flood_image.normalizedDifference(["B3", "B5"]).rename("NDWI")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Compute the NDWI layers for the pre-flood and flood periods side by side.

# %%
Map = geemap.Map()
ndwi_vis = {"min": -1, "max": 1, "palette": "ndwi"}
left_layer = geemap.ee_tile_layer(ndwi_pre, ndwi_vis, "NDWI Pre-flood")
right_layer = geemap.ee_tile_layer(ndwi_post, ndwi_vis, "NDWI Post-flood")
Map.split_map(
    left_layer, right_layer, left_label="NDWI Pre-flood", right_label="NDWI Post-flood"
)
Map.addLayer(roi.style(**style), {}, place_name)
Map.centerObject(roi, 6)
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_302082dd15799cf91e1aaf19365e32ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/digidem/leaflet-side-by-side@gh-pages/leaflet-side-by-side.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_302082dd15799cf91e1aaf19365e32ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_302082dd15799cf91e1aaf19365e32ab = L.map(
#                 &quot;map_302082dd15799cf91e1aaf19365e32ab&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: false,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a19077b9718837c880cd8f93a035357 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7a19077b9718837c880cd8f93a035357.addTo(map_302082dd15799cf91e1aaf19365e32ab);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_302082dd15799cf91e1aaf19365e32ab);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_cd2f1e6d1c0f2fed68e5301f9ec7c4e8 = new L.featureGroup().addTo(
#                 map_302082dd15799cf91e1aaf19365e32ab
#             );
#             options.edit.featureGroup = drawnItems_draw_control_cd2f1e6d1c0f2fed68e5301f9ec7c4e8;
#             var draw_control_cd2f1e6d1c0f2fed68e5301f9ec7c4e8 = new L.Control.Draw(
#                 options
#             ).addTo( map_302082dd15799cf91e1aaf19365e32ab );
#             map_302082dd15799cf91e1aaf19365e32ab.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_cd2f1e6d1c0f2fed68e5301f9ec7c4e8.addLayer(layer);
#              });
#             map_302082dd15799cf91e1aaf19365e32ab.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_cd2f1e6d1c0f2fed68e5301f9ec7c4e8.addLayer(e.layer);
#             });
#
#
#
#
#             var geocoderOpts_geocoder_c71463a58fa756bbe40cf378e238bf56 = {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_c71463a58fa756bbe40cf378e238bf56 = geocoderOpts_geocoder_c71463a58fa756bbe40cf378e238bf56[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_c71463a58fa756bbe40cf378e238bf56 = L.Control.Geocoder[ geocoderName_geocoder_c71463a58fa756bbe40cf378e238bf56 ](
#                 geocoderOpts_geocoder_c71463a58fa756bbe40cf378e238bf56[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_c71463a58fa756bbe40cf378e238bf56[&quot;geocoder&quot;] = customGeocoder_geocoder_c71463a58fa756bbe40cf378e238bf56;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_c71463a58fa756bbe40cf378e238bf56
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_c71463a58fa756bbe40cf378e238bf56[&#x27;zoom&#x27;] || map_302082dd15799cf91e1aaf19365e32ab.getZoom();
#                 map_302082dd15799cf91e1aaf19365e32ab.setView(e.geocode.center, zoom);
#             }).addTo(map_302082dd15799cf91e1a

# %% [markdown]
# ## Extract Landsat water extent
#
# To extract the water extent, we need to convert the NDWI images to binary images using a threshold value. The threshold value is usually set to 0.1 to 0.3. The smaller the threshold value, the more water bodies will be detected, which may increase the false positive rate. The larger the threshold value, the fewer water bodies will be detected, which may increase the false negative rate.

# %%
threshold = 0.1
water_pre = ndwi_pre.gt(threshold)
water_post = ndwi_post.gt(threshold)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Combine the pre-flood and surface water extent side by side.

# %%
Map = geemap.Map()

Map.addLayer(pre_flood_image, vis_params, "Landsat Pre-flood", True)
Map.addLayer(post_flood_image, vis_params, "Landsat Post-flood", True)

left_layer = geemap.ee_tile_layer(
    water_pre.selfMask(), {"palette": "blue"}, "Water Pre-flood"
)
right_layer = geemap.ee_tile_layer(
    water_post.selfMask(), {"palette": "red"}, "Water Post-flood"
)

Map.split_map(
    left_layer,
    right_layer,
    left_label="Water Pre-flood",
    right_label="Water Post-flood",
)
Map.addLayer(roi.style(**style), {}, place_name)
Map.centerObject(roi, 6)
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b95d390afc73637c5dc9cd5fda236c5d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/digidem/leaflet-side-by-side@gh-pages/leaflet-side-by-side.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b95d390afc73637c5dc9cd5fda236c5d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b95d390afc73637c5dc9cd5fda236c5d = L.map(
#                 &quot;map_b95d390afc73637c5dc9cd5fda236c5d&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: false,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_11159d625afe6a289ed7c167d7534f27 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_11159d625afe6a289ed7c167d7534f27.addTo(map_b95d390afc73637c5dc9cd5fda236c5d);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_b95d390afc73637c5dc9cd5fda236c5d);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_bda99016f25e756e2b8e6aae80b6d301 = new L.featureGroup().addTo(
#                 map_b95d390afc73637c5dc9cd5fda236c5d
#             );
#             options.edit.featureGroup = drawnItems_draw_control_bda99016f25e756e2b8e6aae80b6d301;
#             var draw_control_bda99016f25e756e2b8e6aae80b6d301 = new L.Control.Draw(
#                 options
#             ).addTo( map_b95d390afc73637c5dc9cd5fda236c5d );
#             map_b95d390afc73637c5dc9cd5fda236c5d.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_bda99016f25e756e2b8e6aae80b6d301.addLayer(layer);
#              });
#             map_b95d390afc73637c5dc9cd5fda236c5d.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_bda99016f25e756e2b8e6aae80b6d301.addLayer(e.layer);
#             });
#
#
#
#
#             var geocoderOpts_geocoder_86f84ea08b80ef48629b114d68d4a2aa = {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_86f84ea08b80ef48629b114d68d4a2aa = geocoderOpts_geocoder_86f84ea08b80ef48629b114d68d4a2aa[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_86f84ea08b80ef48629b114d68d4a2aa = L.Control.Geocoder[ geocoderName_geocoder_86f84ea08b80ef48629b114d68d4a2aa ](
#                 geocoderOpts_geocoder_86f84ea08b80ef48629b114d68d4a2aa[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_86f84ea08b80ef48629b114d68d4a2aa[&quot;geocoder&quot;] = customGeocoder_geocoder_86f84ea08b80ef48629b114d68d4a2aa;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_86f84ea08b80ef48629b114d68d4a2aa
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_86f84ea08b80ef48629b114d68d4a2aa[&#x27;zoom&#x27;] || map_b95d390afc73637c5dc9cd5fda236c5d.getZoom();
#                 map_b95d390afc73637c5dc9cd5fda236c5d.setView(e.geocode.center, zoom);
#             }).addTo(map_b95d390afc73637c5dc9

# %% [markdown]
# ## Extract Landsat flood extent
#
# To extract the flood extent, we need to subtract the pre-flood water extent from the flood water extent. The flood extent is the difference between the flood water extent and the pre-flood water extent. In other words, pixels identified as water in the flood period but not in the pre-flood period are considered as flooded pixels. The `selfMask()` method is used to mask out the no-data pixels.

# %%
flood_extent = water_post.subtract(water_pre).gt(0).selfMask()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Add the flood extent layer to the map.

# %%
Map = geemap.Map()

Map.addLayer(pre_flood_image, vis_params, "Landsat Pre-flood", True)
Map.addLayer(post_flood_image, vis_params, "Landsat Post-flood", True)

left_layer = geemap.ee_tile_layer(
    water_pre.selfMask(), {"palette": "blue"}, "Water Pre-flood"
)
right_layer = geemap.ee_tile_layer(
    water_post.selfMask(), {"palette": "red"}, "Water Post-flood"
)

Map.split_map(
    left_layer,
    right_layer,
    left_label="Water Pre-flood",
    right_label="Water Post-flood",
)

Map.addLayer(flood_extent, {"palette": "cyan"}, "Flood Extent")
Map.addLayer(roi.style(**style), {}, place_name)
Map.centerObject(roi, 6)
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_18e576e10574e1dcce674b6ac417f9da {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/digidem/leaflet-side-by-side@gh-pages/leaflet-side-by-side.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_18e576e10574e1dcce674b6ac417f9da&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_18e576e10574e1dcce674b6ac417f9da = L.map(
#                 &quot;map_18e576e10574e1dcce674b6ac417f9da&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: false,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5540a923fd1db7c32cdcbfd11c15d11f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5540a923fd1db7c32cdcbfd11c15d11f.addTo(map_18e576e10574e1dcce674b6ac417f9da);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_18e576e10574e1dcce674b6ac417f9da);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_ab717510273bdae99aacdc444cd51250 = new L.featureGroup().addTo(
#                 map_18e576e10574e1dcce674b6ac417f9da
#             );
#             options.edit.featureGroup = drawnItems_draw_control_ab717510273bdae99aacdc444cd51250;
#             var draw_control_ab717510273bdae99aacdc444cd51250 = new L.Control.Draw(
#                 options
#             ).addTo( map_18e576e10574e1dcce674b6ac417f9da );
#             map_18e576e10574e1dcce674b6ac417f9da.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_ab717510273bdae99aacdc444cd51250.addLayer(layer);
#              });
#             map_18e576e10574e1dcce674b6ac417f9da.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_ab717510273bdae99aacdc444cd51250.addLayer(e.layer);
#             });
#
#
#
#
#             var geocoderOpts_geocoder_6b0f1a1e04408b1998514d027b9d1a3e = {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_6b0f1a1e04408b1998514d027b9d1a3e = geocoderOpts_geocoder_6b0f1a1e04408b1998514d027b9d1a3e[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_6b0f1a1e04408b1998514d027b9d1a3e = L.Control.Geocoder[ geocoderName_geocoder_6b0f1a1e04408b1998514d027b9d1a3e ](
#                 geocoderOpts_geocoder_6b0f1a1e04408b1998514d027b9d1a3e[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_6b0f1a1e04408b1998514d027b9d1a3e[&quot;geocoder&quot;] = customGeocoder_geocoder_6b0f1a1e04408b1998514d027b9d1a3e;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_6b0f1a1e04408b1998514d027b9d1a3e
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_6b0f1a1e04408b1998514d027b9d1a3e[&#x27;zoom&#x27;] || map_18e576e10574e1dcce674b6ac417f9da.getZoom();
#                 map_18e576e10574e1dcce674b6ac417f9da.setView(e.geocode.center, zoom);
#             }).addTo(map_18e576e10574e1dcce67

# %% [markdown]
# ## Calculate Landsat flood area
#
# To calculate the flood area, we can use the [`geemap.zonal_stats()`](https://geemap.org/common/#geemap.common.zonal_stats) function. The required input parameters are the flood extent layer and the country boundary layer. The `scale` parameter can be set to `1000` to specify the spatial resolution of image to be used for calculating the zonal statistics. The `stats_type` parameter can be set to `SUM` to calculate the total area of the flood extent in square kilometers. Set `return_fc=True` to return the zonal statistics as an `ee.FeatureCollection` object, which can be converted to a Pandas dataframe.

# %%
area_pre_flood = geemap.zonal_stats(
    water_pre.selfMask(), roi, scale=1000, stat_type="SUM", return_fc=True
)
geemap.ee_to_df(area_pre_flood)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Computing statistics ...
#        area_1  area_tot_g codigo geocodigo  mapid  mslink               nome  \
# 0  281748.155  281748.155     43        43     99     223  RIO GRANDE DO SUL
#
#    perimetro_           sum
# 0  3524.58571  16801.019608

# %%
area_2022 = geemap.zonal_stats(
    water_post.selfMask(), roi, scale=1000, stat_type="SUM", return_fc=True
)
geemap.ee_to_df(area_2022)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Computing statistics ...
#        area_1  area_tot_g codigo geocodigo  mapid  mslink               nome  \
# 0  281748.155  281748.155     43        43     99     223  RIO GRANDE DO SUL
#
#    perimetro_          sum
# 0  3524.58571  1884.207843

# %%
flood_area = geemap.zonal_stats(
    flood_extent.selfMask(), roi, scale=1000, stat_type="SUM", return_fc=True
)
geemap.ee_to_df(flood_area)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Computing statistics ...
#        area_1  area_tot_g codigo geocodigo  mapid  mslink               nome  \
# 0  281748.155  281748.155     43        43     99     223  RIO GRANDE DO SUL
#
#    perimetro_         sum
# 0  3524.58571  634.188235

# %% [markdown]
# ## Create Sentinel-1 SAR composites
#
# Besides Landsat, we can also use Sentinel-1 [Synthetic Aperture Radar (SAR)](https://www.earthdata.nasa.gov/learn/backgrounders/what-is-sar) data to extract flood extent. Radar can collect signals in different polarizations, by controlling the analyzed polarization in both the transmit and receive paths. Signals emitted in vertical (V) and received in horizontal (H) polarization would be indicated by a VH. Alternatively, a signal that was emitted in horizontal (H) and received in horizontal (H) would be indicated by HH, and so on. Examining the signal strength from these different polarizations carries information about the structure of the imaged surface. Rough surface scattering, such as that caused by bare soil or water, is most sensitive to VV scattering. Therefore, VV polarization is often used to detect water bodies.
#
# Sentinel-1 operates in four exclusive [acquisition modes](https://sentinels.copernicus.eu/web/sentinel/missions/sentinel-1/instrument-payload):
#
# * Stripmap (SM)
# * Interferometric Wide swath (IW)
# * Extra-Wide swath (EW)
# * Wave mode (WV)
#
# The Interferometric Wide swath (IW) mode allows combining a large swath width (250 km) with a moderate geometric resolution (5 m by 20 m). The IW mode is the default acquisition mode over land. In this tutorial, we will use Sentinel-1 IW mode data to extract flood extent.
#
# The [Sentinel-1 SAR data](https://developers.google.com/earth-engine/datasets/catalog/COPERNICUS_S1_GRD) are available from 2014 to present. Let's filter the `COPERNICUS/S1_GRD` dataset by the date range and location.

# %%
pre_flood_start_date = "2023-10-01"
pre_flood_end_date = "2024-04-27"
post_flood_start_date = "2024-04-29"
post_flood_end_date = "2024-05-17"
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
s1_col_pre = (
    ee.ImageCollection("COPERNICUS/S1_GRD")
    .filter(ee.Filter.listContains("transmitterReceiverPolarisation", "VV"))
    .filter(ee.Filter.eq("instrumentMode", "IW"))
    .filterDate(pre_flood_start_date, pre_flood_end_date)
    .filterBounds(roi)
    .select("VV")
)
print(
    f"The number of images in the pre-flood collection: {s1_col_pre.size().getInfo()}"
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# The number of images in the pre-flood collection: 161

# %% [markdown]
# Create the Sentinel-1 image collection for the flood period.

# %%
s1_col_post = (
    ee.ImageCollection("COPERNICUS/S1_GRD")
    .filter(ee.Filter.listContains("transmitterReceiverPolarisation", "VV"))
    .filter(ee.Filter.eq("instrumentMode", "IW"))
    # .filter(ee.Filter.eq('orbitProperties_pass', 'ASCENDING'))
    .filterDate(post_flood_start_date, post_flood_end_date)
    .filterBounds(roi)
    .select("VV")
)
print(
    f"The number of images in the post-flood collection: {s1_col_post.size().getInfo()}"
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# The number of images in the post-flood collection: 19

# %% [markdown]
# Create Sentinel-1 SAR composites for the pre-flood and flood periods.

# %%
Map = geemap.Map()
Map.add_basemap("Esri.WorldImagery")
sar_pre = s1_col_pre.reduce(ee.Reducer.percentile([20])).clipToCollection(roi)
sar_post = s1_col_post.reduce(ee.Reducer.percentile([20])).clipToCollection(roi)
Map.addLayer(sar_pre, {"min": -25, "max": -5}, "SAR Pre-flood")
Map.addLayer(sar_post, {"min": -25, "max": -5}, "SAR Post-flood")
Map.addLayer(roi.style(**style), {}, place_name)
Map.centerObject(roi, 6)
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3cd2b0002f47061ae5c200ba7b8e5dd3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3cd2b0002f47061ae5c200ba7b8e5dd3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3cd2b0002f47061ae5c200ba7b8e5dd3 = L.map(
#                 &quot;map_3cd2b0002f47061ae5c200ba7b8e5dd3&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: false,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15e4e0dd74cce682e9c2ea73f24d5549 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_15e4e0dd74cce682e9c2ea73f24d5549.addTo(map_3cd2b0002f47061ae5c200ba7b8e5dd3);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_3cd2b0002f47061ae5c200ba7b8e5dd3);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_637d561bff2f84d78109767bfff5083d = new L.featureGroup().addTo(
#                 map_3cd2b0002f47061ae5c200ba7b8e5dd3
#             );
#             options.edit.featureGroup = drawnItems_draw_control_637d561bff2f84d78109767bfff5083d;
#             var draw_control_637d561bff2f84d78109767bfff5083d = new L.Control.Draw(
#                 options
#             ).addTo( map_3cd2b0002f47061ae5c200ba7b8e5dd3 );
#             map_3cd2b0002f47061ae5c200ba7b8e5dd3.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_637d561bff2f84d78109767bfff5083d.addLayer(layer);
#              });
#             map_3cd2b0002f47061ae5c200ba7b8e5dd3.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_637d561bff2f84d78109767bfff5083d.addLayer(e.layer);
#             });
#
#
#
#
#             var geocoderOpts_geocoder_ec4c5be01a61636be95abbc8634e11ca = {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_ec4c5be01a61636be95abbc8634e11ca = geocoderOpts_geocoder_ec4c5be01a61636be95abbc8634e11ca[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_ec4c5be01a61636be95abbc8634e11ca = L.Control.Geocoder[ geocoderName_geocoder_ec4c5be01a61636be95abbc8634e11ca ](
#                 geocoderOpts_geocoder_ec4c5be01a61636be95abbc8634e11ca[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_ec4c5be01a61636be95abbc8634e11ca[&quot;geocoder&quot;] = customGeocoder_geocoder_ec4c5be01a61636be95abbc8634e11ca;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_ec4c5be01a61636be95abbc8634e11ca
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_ec4c5be01a61636be95abbc8634e11ca[&#x27;zoom&#x27;] || map_3cd2b0002f47061ae5c200ba7b8e5dd3.getZoom();
#                 map_3cd2b0002f47061ae5c200ba7b8e5dd3.setView(e.geocode.center, zoom);
#             }).addTo(map_3cd2b0002f47061ae5c200ba7b8e5dd3);
#
#
#
#             map_3cd2b0002f47061ae5c200ba7b8e5dd3.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&

# %% [markdown]
# ## Apply speckle filtering
#
# Speckle, appearing in synthetic aperture radar (SAR) images as granular noise, is due to the interference of waves reflected from many elementary scatterers. Speckle in SAR images complicates the image interpretation problem by reducing the effectiveness of image segmentation and classification ([Lee et al., 1994](https://doi.org/10.1080/02757259409532206)). Therefore, speckle filtering is often applied to SAR images to reduce the speckle noise. In this example, we apply a morphological speckle filter to the Sentinel-1 SAR images. The morphological speckle filter is a non-linear filter that uses the median value of a pixel and its neighboring pixels to replace the pixel value. The kernel size is set to 100 meters.

# %%
s1_col_pre = s1_col_pre.map(lambda img: img.focal_median(100, "circle", "meters"))
s1_col_post = s1_col_post.map(lambda img: img.focal_median(100, "circle", "meters"))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
Map = geemap.Map()
Map.add_basemap("Esri.WorldImagery")
sar_pre = s1_col_pre.reduce(ee.Reducer.percentile([20])).clipToCollection(roi)
sar_post = s1_col_post.reduce(ee.Reducer.percentile([20])).clipToCollection(roi)
Map.addLayer(sar_pre, {"min": -25, "max": -5}, "SAR Pre-flood")
Map.addLayer(sar_post, {"min": -25, "max": -5}, "SAR Post-flood")
Map.addLayer(roi.style(**style), {}, place_name)
Map.centerObject(roi, 6)
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7f357ed2aefa854f177c30ea23c6c302 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7f357ed2aefa854f177c30ea23c6c302&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7f357ed2aefa854f177c30ea23c6c302 = L.map(
#                 &quot;map_7f357ed2aefa854f177c30ea23c6c302&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: false,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fa746ca872861a1b6dc292c579a22ee8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fa746ca872861a1b6dc292c579a22ee8.addTo(map_7f357ed2aefa854f177c30ea23c6c302);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_7f357ed2aefa854f177c30ea23c6c302);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_7d605b2252f0a3b7f0b593485b000b11 = new L.featureGroup().addTo(
#                 map_7f357ed2aefa854f177c30ea23c6c302
#             );
#             options.edit.featureGroup = drawnItems_draw_control_7d605b2252f0a3b7f0b593485b000b11;
#             var draw_control_7d605b2252f0a3b7f0b593485b000b11 = new L.Control.Draw(
#                 options
#             ).addTo( map_7f357ed2aefa854f177c30ea23c6c302 );
#             map_7f357ed2aefa854f177c30ea23c6c302.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_7d605b2252f0a3b7f0b593485b000b11.addLayer(layer);
#              });
#             map_7f357ed2aefa854f177c30ea23c6c302.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_7d605b2252f0a3b7f0b593485b000b11.addLayer(e.layer);
#             });
#
#
#
#
#             var geocoderOpts_geocoder_742f85a4dd4b3b197ffaf8466505be02 = {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_742f85a4dd4b3b197ffaf8466505be02 = geocoderOpts_geocoder_742f85a4dd4b3b197ffaf8466505be02[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_742f85a4dd4b3b197ffaf8466505be02 = L.Control.Geocoder[ geocoderName_geocoder_742f85a4dd4b3b197ffaf8466505be02 ](
#                 geocoderOpts_geocoder_742f85a4dd4b3b197ffaf8466505be02[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_742f85a4dd4b3b197ffaf8466505be02[&quot;geocoder&quot;] = customGeocoder_geocoder_742f85a4dd4b3b197ffaf8466505be02;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_742f85a4dd4b3b197ffaf8466505be02
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_742f85a4dd4b3b197ffaf8466505be02[&#x27;zoom&#x27;] || map_7f357ed2aefa854f177c30ea23c6c302.getZoom();
#                 map_7f357ed2aefa854f177c30ea23c6c302.setView(e.geocode.center, zoom);
#             }).addTo(map_7f357ed2aefa854f177c30ea23c6c302);
#
#
#
#             map_7f357ed2aefa854f177c30ea23c6c302.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&

# %% [markdown]
# ## Compare Sentinel-1 SAR composites side by side
#
# Create a split-view map to compare the pre-flood and flood SAR composites side by side.

# %%
Map = geemap.Map()
left_layer = geemap.ee_tile_layer(sar_pre, {"min": -25, "max": -5}, "SAR Pre-flood")
right_layer = geemap.ee_tile_layer(sar_post, {"min": -25, "max": -5}, "SAR Post-flood")

Map.split_map(
    left_layer,
    right_layer,
    left_label="Sentinel-1 Pre-flood",
    right_label="Sentinel-1 Post_flood",
)
Map.addLayer(roi.style(**style), {}, place_name)
Map.centerObject(roi, 6)
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b41ab19589949fe452ed2eb8c1e88c4d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/digidem/leaflet-side-by-side@gh-pages/leaflet-side-by-side.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b41ab19589949fe452ed2eb8c1e88c4d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b41ab19589949fe452ed2eb8c1e88c4d = L.map(
#                 &quot;map_b41ab19589949fe452ed2eb8c1e88c4d&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: false,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c0d1ca32e2b0d2cf355e404867cf055c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c0d1ca32e2b0d2cf355e404867cf055c.addTo(map_b41ab19589949fe452ed2eb8c1e88c4d);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_b41ab19589949fe452ed2eb8c1e88c4d);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_e78eb745e94d3f5a436fe6d74b18604e = new L.featureGroup().addTo(
#                 map_b41ab19589949fe452ed2eb8c1e88c4d
#             );
#             options.edit.featureGroup = drawnItems_draw_control_e78eb745e94d3f5a436fe6d74b18604e;
#             var draw_control_e78eb745e94d3f5a436fe6d74b18604e = new L.Control.Draw(
#                 options
#             ).addTo( map_b41ab19589949fe452ed2eb8c1e88c4d );
#             map_b41ab19589949fe452ed2eb8c1e88c4d.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_e78eb745e94d3f5a436fe6d74b18604e.addLayer(layer);
#              });
#             map_b41ab19589949fe452ed2eb8c1e88c4d.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_e78eb745e94d3f5a436fe6d74b18604e.addLayer(e.layer);
#             });
#
#
#
#
#             var geocoderOpts_geocoder_3c4caf94cc5bf2094ddfea19c706c499 = {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_3c4caf94cc5bf2094ddfea19c706c499 = geocoderOpts_geocoder_3c4caf94cc5bf2094ddfea19c706c499[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_3c4caf94cc5bf2094ddfea19c706c499 = L.Control.Geocoder[ geocoderName_geocoder_3c4caf94cc5bf2094ddfea19c706c499 ](
#                 geocoderOpts_geocoder_3c4caf94cc5bf2094ddfea19c706c499[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_3c4caf94cc5bf2094ddfea19c706c499[&quot;geocoder&quot;] = customGeocoder_geocoder_3c4caf94cc5bf2094ddfea19c706c499;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_3c4caf94cc5bf2094ddfea19c706c499
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_3c4caf94cc5bf2094ddfea19c706c499[&#x27;zoom&#x27;] || map_b41ab19589949fe452ed2eb8c1e88c4d.getZoom();
#                 map_b41ab19589949fe452ed2eb8c1e88c4d.setView(e.geocode.center, zoom);
#             }).addTo(map_b41ab19589949fe452ed

# %% [markdown]
# ## Extract SAR water extent
#
# Water usually appears dark in SAR images because radar waves are reflected differently by different surfaces. Water is a smooth, flat surface that does not reflect radar waves very well, so it appears dark in SAR images. Thresholding SAR imagery is one of the most widely used approaches to delineate water extent for its effectiveness and efficiency ([Liang and Liu, 2020](https://doi.org/10.1016/j.isprsjprs.2019.10.017)). Thresholding methods can be generally divided into two categories: global and local. Global thresholding methods use a single threshold value to segment the entire image. Local thresholding methods use a different threshold value for each pixel. In this example, we use a global thresholding method to extract the water extent. The threshold value is set to -18
# dB.

# %%
threshold = -18
water_pre = sar_pre.lt(threshold)
water_post = sar_post.lt(threshold)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Create a split-view map to compare the pre-flood and flood water extent side by side.

# %%
Map = geemap.Map()
Map.addLayer(sar_pre, {"min": -25, "max": -5}, "SAR Pre-flood")
Map.addLayer(sar_post, {"min": -25, "max": -5}, "SAR Post-flood")

left_layer = geemap.ee_tile_layer(
    water_pre.selfMask(), {"palette": "blue"}, "Water Pre-flood"
)
right_layer = geemap.ee_tile_layer(
    water_post.selfMask(), {"palette": "red"}, "Water Post-flood"
)

Map.split_map(
    left_layer,
    right_layer,
    left_label="Water Pre-flood",
    right_label="Water Post-flood",
)
Map.addLayer(roi.style(**style), {}, place_name)
Map.centerObject(roi, 6)
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d08a05e8e1d36dbc7bc9462de16c28e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/digidem/leaflet-side-by-side@gh-pages/leaflet-side-by-side.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d08a05e8e1d36dbc7bc9462de16c28e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d08a05e8e1d36dbc7bc9462de16c28e = L.map(
#                 &quot;map_6d08a05e8e1d36dbc7bc9462de16c28e&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: false,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a814cfb6325a9aadd9256370567a62e4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a814cfb6325a9aadd9256370567a62e4.addTo(map_6d08a05e8e1d36dbc7bc9462de16c28e);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_6d08a05e8e1d36dbc7bc9462de16c28e);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_e790380a36bc381ce643c0f30e5d42fd = new L.featureGroup().addTo(
#                 map_6d08a05e8e1d36dbc7bc9462de16c28e
#             );
#             options.edit.featureGroup = drawnItems_draw_control_e790380a36bc381ce643c0f30e5d42fd;
#             var draw_control_e790380a36bc381ce643c0f30e5d42fd = new L.Control.Draw(
#                 options
#             ).addTo( map_6d08a05e8e1d36dbc7bc9462de16c28e );
#             map_6d08a05e8e1d36dbc7bc9462de16c28e.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_e790380a36bc381ce643c0f30e5d42fd.addLayer(layer);
#              });
#             map_6d08a05e8e1d36dbc7bc9462de16c28e.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_e790380a36bc381ce643c0f30e5d42fd.addLayer(e.layer);
#             });
#
#
#
#
#             var geocoderOpts_geocoder_186589cd4c88da6bd71afabddba2137a = {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_186589cd4c88da6bd71afabddba2137a = geocoderOpts_geocoder_186589cd4c88da6bd71afabddba2137a[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_186589cd4c88da6bd71afabddba2137a = L.Control.Geocoder[ geocoderName_geocoder_186589cd4c88da6bd71afabddba2137a ](
#                 geocoderOpts_geocoder_186589cd4c88da6bd71afabddba2137a[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_186589cd4c88da6bd71afabddba2137a[&quot;geocoder&quot;] = customGeocoder_geocoder_186589cd4c88da6bd71afabddba2137a;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_186589cd4c88da6bd71afabddba2137a
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_186589cd4c88da6bd71afabddba2137a[&#x27;zoom&#x27;] || map_6d08a05e8e1d36dbc7bc9462de16c28e.getZoom();
#                 map_6d08a05e8e1d36dbc7bc9462de16c28e.setView(e.geocode.center, zoom);
#             }).addTo(map_6d08a05e8e1d36dbc7bc

# %% [markdown]
# ## Extract SAR flood extent
#
# Similar to the Landsat approach, we can subtract the pre-flood water extent from the flood water extent to extract the flood extent.

# %%
flood_extent = water_post.subtract(water_pre).gt(0).selfMask()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# The flood extent is the difference between the flood water extent and the pre-flood water extent. In other words, pixels identified as water in the flood period but not in the pre-flood period are considered as flooded pixels, which are shown in cyan.

# %%
Map = geemap.Map()

Map.addLayer(sar_pre, {"min": -25, "max": -5}, "SAR Pre-flood")
Map.addLayer(sar_post, {"min": -25, "max": -5}, "SAR Post-flood")

left_layer = geemap.ee_tile_layer(
    water_pre.selfMask(), {"palette": "blue"}, "Water Pre-flood"
)
right_layer = geemap.ee_tile_layer(
    water_post.selfMask(), {"palette": "red"}, "Water Post-flood"
)

Map.split_map(
    left_layer,
    right_layer,
    left_label="Water Pre-flood",
    right_label="Water Post-flood",
)

Map.addLayer(flood_extent, {"palette": "cyan"}, "Flood Extent")
Map.addLayer(roi.style(**style), {}, place_name)
Map.centerObject(roi, 6)
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7b833379df78ff77ca79cba1881354ba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/digidem/leaflet-side-by-side@gh-pages/leaflet-side-by-side.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7b833379df78ff77ca79cba1881354ba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7b833379df78ff77ca79cba1881354ba = L.map(
#                 &quot;map_7b833379df78ff77ca79cba1881354ba&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: false,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a85badb220d16d64144a5331d8918bd9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a85badb220d16d64144a5331d8918bd9.addTo(map_7b833379df78ff77ca79cba1881354ba);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_7b833379df78ff77ca79cba1881354ba);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_669edc684c13ce155378c3a25b8694cc = new L.featureGroup().addTo(
#                 map_7b833379df78ff77ca79cba1881354ba
#             );
#             options.edit.featureGroup = drawnItems_draw_control_669edc684c13ce155378c3a25b8694cc;
#             var draw_control_669edc684c13ce155378c3a25b8694cc = new L.Control.Draw(
#                 options
#             ).addTo( map_7b833379df78ff77ca79cba1881354ba );
#             map_7b833379df78ff77ca79cba1881354ba.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_669edc684c13ce155378c3a25b8694cc.addLayer(layer);
#              });
#             map_7b833379df78ff77ca79cba1881354ba.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_669edc684c13ce155378c3a25b8694cc.addLayer(e.layer);
#             });
#
#
#
#
#             var geocoderOpts_geocoder_33fa82caf2df055d958b561aa7fcaf4b = {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_33fa82caf2df055d958b561aa7fcaf4b = geocoderOpts_geocoder_33fa82caf2df055d958b561aa7fcaf4b[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_33fa82caf2df055d958b561aa7fcaf4b = L.Control.Geocoder[ geocoderName_geocoder_33fa82caf2df055d958b561aa7fcaf4b ](
#                 geocoderOpts_geocoder_33fa82caf2df055d958b561aa7fcaf4b[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_33fa82caf2df055d958b561aa7fcaf4b[&quot;geocoder&quot;] = customGeocoder_geocoder_33fa82caf2df055d958b561aa7fcaf4b;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_33fa82caf2df055d958b561aa7fcaf4b
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_33fa82caf2df055d958b561aa7fcaf4b[&#x27;zoom&#x27;] || map_7b833379df78ff77ca79cba1881354ba.getZoom();
#                 map_7b833379df78ff77ca79cba1881354ba.setView(e.geocode.center, zoom);
#             }).addTo(map_7b833379df78ff77ca79

# %% [markdown]
# ## Calculate SAR flood area

# %%
area_pre_flood = geemap.zonal_stats(
    water_pre.selfMask(), roi, scale=1000, stat_type="SUM", return_fc=True
)
geemap.ee_to_df(area_pre_flood)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Computing statistics ...
#        area_1  area_tot_g codigo geocodigo  mapid  mslink               nome  \
# 0  281748.155  281748.155     43        43     99     223  RIO GRANDE DO SUL
#
#    perimetro_           sum
# 0  3524.58571  10160.776471

# %%
area_2022 = geemap.zonal_stats(
    water_post.selfMask(), roi, scale=1000, stat_type="SUM", return_fc=True
)
geemap.ee_to_df(area_2022)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Computing statistics ...
#        area_1  area_tot_g codigo geocodigo  mapid  mslink               nome  \
# 0  281748.155  281748.155     43        43     99     223  RIO GRANDE DO SUL
#
#    perimetro_           sum
# 0  3524.58571  13054.921569

# %%
flood_area = geemap.zonal_stats(
    flood_extent.selfMask(), roi, scale=1000, stat_type="SUM", return_fc=True
)
geemap.ee_to_df(flood_area)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Computing statistics ...
#        area_1  area_tot_g codigo geocodigo  mapid  mslink               nome  \
# 0  281748.155  281748.155     43        43     99     223  RIO GRANDE DO SUL
#
#    perimetro_          sum
# 0  3524.58571  5745.360784
