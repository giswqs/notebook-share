# %% [markdown]
# [![Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/giswqs/notebook-share/blob/master/docs/dongting_lake_floods.ipynb)
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/giswqs/notebook-share/HEAD?labpath=docs%dongting_lake_floods.ipynb)

# %% [markdown]
# # Visualization and Analysis of Dongting Lake Floods 2024

# %% [markdown]
# ## Introduction
#
# Dongting Lake, China's second-largest freshwater lake, burst its embankment on July 5, 2024, flooding more than 47 sq km (18 square miles). The floods have affected more than 364,000 people, inundated farmland, damaged over 2,600 sections of roads and bridges and caused multiple landslides in Pingjiang. For more information, please refer to the [South China Morning Post](https://www.scmp.com/news/china/article/3269424/dyke-breach-chinas-no-2-freshwater-lake-dongting-sparks-emergency-evacuation).
#
#
# ![](https://multimedia.scmp.com/embeds/2024/china/dongting_lake_flood/images/static-d.jpg)
#
# ## Requirements
#
# To follow this tutorial, you must first [sign up](https://earthengine.google.com/signup) for a [Google Earth Engine](https://earthengine.google.com/) account. Earth Engine is a cloud computing platform with a [multi-petabyte catalog](https://developers.google.com/earth-engine/datasets/) of satellite imagery and geospatial datasets. It is free for noncommercial use. To authenticate the Earth Engine Python API, see instructions [here](https://book.geemap.org/chapters/01_introduction.html#earth-engine-authentication).
#
# In this tutorial, we will use the [geemap](https://geemap.org) Python package to visualize and analyze the Dongting Lake floods. Geemap enables users to analyze and visualize Earth Engine datasets interactively within a Jupyter-based environment with minimal coding. To learn more about geemap, check out https://geemap.org.

# %% [markdown]
# ## Installation
#
# Uncomment the following line to install geemap if needed.

# %%
# %pip install -U geemap

# %% [markdown]
# ## Import libraries
#
# Import the earthengine-api and geemap.

# %%
import ee
import geemap.foliumap as geemap

# %%
geemap.ee_initialize()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Create an interactive map

# %%
m = geemap.Map(center=[29.343875, 112.986832], zoom=11)
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_23ef26db27bb79f4533ab8388922cd33 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_23ef26db27bb79f4533ab8388922cd33&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_23ef26db27bb79f4533ab8388922cd33 = L.map(
#                 &quot;map_23ef26db27bb79f4533ab8388922cd33&quot;,
#                 {
#                     center: [29.343875, 112.986832],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: false,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a2f5bc50ab65b6b1226d33b63f1afc3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7a2f5bc50ab65b6b1226d33b63f1afc3.addTo(map_23ef26db27bb79f4533ab8388922cd33);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_23ef26db27bb79f4533ab8388922cd33);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_29d1bbc0a71705dca72bfa3007d3df66 = new L.featureGroup().addTo(
#                 map_23ef26db27bb79f4533ab8388922cd33
#             );
#             options.edit.featureGroup = drawnItems_draw_control_29d1bbc0a71705dca72bfa3007d3df66;
#             var draw_control_29d1bbc0a71705dca72bfa3007d3df66 = new L.Control.Draw(
#                 options
#             ).addTo( map_23ef26db27bb79f4533ab8388922cd33 );
#             map_23ef26db27bb79f4533ab8388922cd33.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_29d1bbc0a71705dca72bfa3007d3df66.addLayer(layer);
#              });
#             map_23ef26db27bb79f4533ab8388922cd33.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_29d1bbc0a71705dca72bfa3007d3df66.addLayer(e.layer);
#             });
#
#
#
#
#             var geocoderOpts_geocoder_6796ddd4ea0d338f2a339c161532f585 = {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_6796ddd4ea0d338f2a339c161532f585 = geocoderOpts_geocoder_6796ddd4ea0d338f2a339c161532f585[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_6796ddd4ea0d338f2a339c161532f585 = L.Control.Geocoder[ geocoderName_geocoder_6796ddd4ea0d338f2a339c161532f585 ](
#                 geocoderOpts_geocoder_6796ddd4ea0d338f2a339c161532f585[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_6796ddd4ea0d338f2a339c161532f585[&quot;geocoder&quot;] = customGeocoder_geocoder_6796ddd4ea0d338f2a339c161532f585;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_6796ddd4ea0d338f2a339c161532f585
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_6796ddd4ea0d338f2a339c161532f585[&#x27;zoom&#x27;] || map_23ef26db27bb79f4533ab8388922cd33.getZoom();
#                 map_23ef26db27bb79f4533ab8388922cd33.setView(e.geocode.center, zoom);
#             }).addTo(map_23ef26db27bb79f4533ab8388922cd33);
#
#
#
#             map_23ef26db27bb79f4533ab8388922cd33.fitBounds(
#                 [[29.343875, 112.986832],

# %% [markdown]
# ## Specify ROI and time range
#
# In the tutorial, we will focus on the Dongting Lake in China, but the code can be easily modified to visualize and analyze floods in other countries or regions. Modify the `geom` variable to specify the place of interest and set the date range for the flood event. In order to extract the flood extent, we also need to specify the date range for the pre-flood period.

# %%
m = geemap.Map()
m.add_basemap("HYBRID")
geom = ee.Geometry.Polygon(
    [
        [
            [112.755432, 29.642708],
            [112.359924, 28.591757],
            [113.414612, 28.586933],
            [113.755188, 29.652256],
            [112.755432, 29.642708],
        ]
    ]
)
roi = ee.FeatureCollection(geom)

jrc = ee.Image("JRC/GSW1_4/GlobalSurfaceWater").clipToCollection(roi)
vis_params = {
    "bands": ["occurrence"],
    "min": 0.0,
    "max": 100.0,
    "palette": ["ffffff", "ffbbbb", "0000ff"],
}
m.add_layer(jrc, vis_params, "Water Occurrence")
m.add_layer(geom, {}, "ROI")
m.center_object(geom)
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b6b52eaed9e6b8700f1648c289c9985 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b6b52eaed9e6b8700f1648c289c9985&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9b6b52eaed9e6b8700f1648c289c9985 = L.map(
#                 &quot;map_9b6b52eaed9e6b8700f1648c289c9985&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: false,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_48340dfbfdfe422165b4de2ec73b611e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_48340dfbfdfe422165b4de2ec73b611e.addTo(map_9b6b52eaed9e6b8700f1648c289c9985);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_9b6b52eaed9e6b8700f1648c289c9985);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_761b901b4fc55236830e201a6ab8edba = new L.featureGroup().addTo(
#                 map_9b6b52eaed9e6b8700f1648c289c9985
#             );
#             options.edit.featureGroup = drawnItems_draw_control_761b901b4fc55236830e201a6ab8edba;
#             var draw_control_761b901b4fc55236830e201a6ab8edba = new L.Control.Draw(
#                 options
#             ).addTo( map_9b6b52eaed9e6b8700f1648c289c9985 );
#             map_9b6b52eaed9e6b8700f1648c289c9985.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_761b901b4fc55236830e201a6ab8edba.addLayer(layer);
#              });
#             map_9b6b52eaed9e6b8700f1648c289c9985.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_761b901b4fc55236830e201a6ab8edba.addLayer(e.layer);
#             });
#
#
#
#
#             var geocoderOpts_geocoder_7d435e8aa50d9f95f39971413367c609 = {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_7d435e8aa50d9f95f39971413367c609 = geocoderOpts_geocoder_7d435e8aa50d9f95f39971413367c609[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_7d435e8aa50d9f95f39971413367c609 = L.Control.Geocoder[ geocoderName_geocoder_7d435e8aa50d9f95f39971413367c609 ](
#                 geocoderOpts_geocoder_7d435e8aa50d9f95f39971413367c609[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_7d435e8aa50d9f95f39971413367c609[&quot;geocoder&quot;] = customGeocoder_geocoder_7d435e8aa50d9f95f39971413367c609;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_7d435e8aa50d9f95f39971413367c609
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_7d435e8aa50d9f95f39971413367c609[&#x27;zoom&#x27;] || map_9b6b52eaed9e6b8700f1648c289c9985.getZoom();
#                 map_9b6b52eaed9e6b8700f1648c289c9985.setView(e.geocode.center, zoom);
#             }).addTo(map_9b6b52eaed9e6b8700f1648c289c9985);
#
#
#
#             map_9b6b52eaed9e6b8700f1648c289c9985.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&

# %%
pre_flood_start_date = "2024-01-01"
pre_flood_end_date = "2024-07-04"
post_flood_start_date = "2024-07-05"
post_flood_end_date = "2024-07-17"
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Create Landsat composites
#
# Create a Landsat composite for the pre-flood period using the [Harmonized Landsat Data](https://developers.google.com/earth-engine/datasets/catalog/NASA_HLS_HLSL30_v002).

# %%
pre_flood_col = (
    ee.ImageCollection("NASA/HLS/HLSL30/v002")
    .filterBounds(roi)
    .filterDate(pre_flood_start_date, pre_flood_end_date)
    .filter(ee.Filter.lt("CLOUD_COVERAGE", 25))
)
print(
    f"The number of images in the pre-flood collection: {pre_flood_col.size().getInfo()}"
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# The number of images in the pre-flood collection: 20

# %% [markdown]
# Create a Landsat composite for the post-flood period using the [Harmonized Landsat Data](https://developers.google.com/earth-engine/datasets/catalog/NASA_HLS_HLSL30_v002).

# %%
post_flood_col = (
    ee.ImageCollection("NASA/HLS/HLSL30/v002")
    .filterBounds(roi)
    .filterDate(post_flood_start_date, post_flood_end_date)
    .filter(ee.Filter.lt("CLOUD_COVERAGE", 50))
)
print(
    f"The number of images in the post-flood collection: {post_flood_col.size().getInfo()}"
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# The number of images in the post-flood collection: 5

# %% [markdown]
# Visualize the Landsat composite for the pre-flood and flood periods.

# %%
m = geemap.Map()

pre_flood_image = pre_flood_col.median().clipToCollection(roi)
post_flood_image = post_flood_col.median().clipToCollection(roi)

vis_params = {"bands": ["B6", "B5", "B4"], "min": 0, "max": 0.4}
m.add_layer(pre_flood_image, vis_params, "Landsat Pre-flood")
m.add_layer(post_flood_image, vis_params, "Landsat Post-flood")
m.center_object(roi, 9)
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70d4711d94bef1477de88f0128c50e11 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70d4711d94bef1477de88f0128c50e11&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_70d4711d94bef1477de88f0128c50e11 = L.map(
#                 &quot;map_70d4711d94bef1477de88f0128c50e11&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: false,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1324034c7822c1e2f6d865556ef55733 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1324034c7822c1e2f6d865556ef55733.addTo(map_70d4711d94bef1477de88f0128c50e11);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_70d4711d94bef1477de88f0128c50e11);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_8013b839b8079050fe6dfee057a49716 = new L.featureGroup().addTo(
#                 map_70d4711d94bef1477de88f0128c50e11
#             );
#             options.edit.featureGroup = drawnItems_draw_control_8013b839b8079050fe6dfee057a49716;
#             var draw_control_8013b839b8079050fe6dfee057a49716 = new L.Control.Draw(
#                 options
#             ).addTo( map_70d4711d94bef1477de88f0128c50e11 );
#             map_70d4711d94bef1477de88f0128c50e11.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_8013b839b8079050fe6dfee057a49716.addLayer(layer);
#              });
#             map_70d4711d94bef1477de88f0128c50e11.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_8013b839b8079050fe6dfee057a49716.addLayer(e.layer);
#             });
#
#
#
#
#             var geocoderOpts_geocoder_2c49557891b3a3d5cd6d5ee22b885b79 = {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_2c49557891b3a3d5cd6d5ee22b885b79 = geocoderOpts_geocoder_2c49557891b3a3d5cd6d5ee22b885b79[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_2c49557891b3a3d5cd6d5ee22b885b79 = L.Control.Geocoder[ geocoderName_geocoder_2c49557891b3a3d5cd6d5ee22b885b79 ](
#                 geocoderOpts_geocoder_2c49557891b3a3d5cd6d5ee22b885b79[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_2c49557891b3a3d5cd6d5ee22b885b79[&quot;geocoder&quot;] = customGeocoder_geocoder_2c49557891b3a3d5cd6d5ee22b885b79;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_2c49557891b3a3d5cd6d5ee22b885b79
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_2c49557891b3a3d5cd6d5ee22b885b79[&#x27;zoom&#x27;] || map_70d4711d94bef1477de88f0128c50e11.getZoom();
#                 map_70d4711d94bef1477de88f0128c50e11.setView(e.geocode.center, zoom);
#             }).addTo(map_70d4711d94bef1477de88f0128c50e11);
#
#
#
#             map_70d4711d94bef1477de88f0128c50e11.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&

# %% [markdown]
# ## Compare Landsat composites side by side
#
# Compare the pre-flood and flood composites side by side.

# %%
m = geemap.Map()
left_layer = geemap.ee_tile_layer(pre_flood_image, vis_params, "Landsat Pre-flood")
right_layer = geemap.ee_tile_layer(post_flood_image, vis_params, "Landsat Post-flood")
m.split_map(
    left_layer,
    right_layer,
    left_label="Landsat Pre-flood",
    right_label="Landsat Post-flood",
)
m.center_object(roi, 9)
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff36258486367688e255996534db336e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/digidem/leaflet-side-by-side@2.0.0/leaflet-side-by-side.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff36258486367688e255996534db336e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ff36258486367688e255996534db336e = L.map(
#                 &quot;map_ff36258486367688e255996534db336e&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: false,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cf6d66ccba7b9d0439f4b80251227ee8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cf6d66ccba7b9d0439f4b80251227ee8.addTo(map_ff36258486367688e255996534db336e);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_ff36258486367688e255996534db336e);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_9751c8f1a7724d79beec543d17c136c3 = new L.featureGroup().addTo(
#                 map_ff36258486367688e255996534db336e
#             );
#             options.edit.featureGroup = drawnItems_draw_control_9751c8f1a7724d79beec543d17c136c3;
#             var draw_control_9751c8f1a7724d79beec543d17c136c3 = new L.Control.Draw(
#                 options
#             ).addTo( map_ff36258486367688e255996534db336e );
#             map_ff36258486367688e255996534db336e.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_9751c8f1a7724d79beec543d17c136c3.addLayer(layer);
#              });
#             map_ff36258486367688e255996534db336e.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_9751c8f1a7724d79beec543d17c136c3.addLayer(e.layer);
#             });
#
#
#
#
#             var geocoderOpts_geocoder_09877b6331ad046fbe96b9e5bdd80d8e = {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_09877b6331ad046fbe96b9e5bdd80d8e = geocoderOpts_geocoder_09877b6331ad046fbe96b9e5bdd80d8e[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_09877b6331ad046fbe96b9e5bdd80d8e = L.Control.Geocoder[ geocoderName_geocoder_09877b6331ad046fbe96b9e5bdd80d8e ](
#                 geocoderOpts_geocoder_09877b6331ad046fbe96b9e5bdd80d8e[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_09877b6331ad046fbe96b9e5bdd80d8e[&quot;geocoder&quot;] = customGeocoder_geocoder_09877b6331ad046fbe96b9e5bdd80d8e;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_09877b6331ad046fbe96b9e5bdd80d8e
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_09877b6331ad046fbe96b9e5bdd80d8e[&#x27;zoom&#x27;] || map_ff36258486367688e255996534db336e.getZoom();
#                 map_ff36258486367688e255996534db336e.setView(e.geocode.center, zoom);
#             }).addTo(map_ff36258486367688e255996

# %% [markdown]
# ## Compute Normalized Difference Water Index (NDWI)
#
# The [Normalized Difference Water Index](https://en.wikipedia.org/wiki/Normalized_difference_water_index) (NDWI) is a commonly used index for detecting water bodies. It is calculated as follows:
#
# $$NDWI = \frac{Green - NIR}{Green + NIR}$$
#
# where Green is the green band and NIR is the near-infrared band. The NDWI values range from -1 to 1. The NDWI values are usually thresholded to a positive number (e.g., 0.1-0.3) to identify water bodies.
#
# Landsat 8 imagery has [11 spectral bands](https://developers.google.com/earth-engine/datasets/catalog/LANDSAT_LC08_C02_T1#bands). The Landsat 8 NDWI is calculated using the green (`B3`) and NIR (`B5`) bands.
#
# ![](https://i.imgur.com/yuZthc6.png)

# %%
ndwi_pre = pre_flood_image.normalizedDifference(["B3", "B5"]).rename("NDWI")
ndwi_post = post_flood_image.normalizedDifference(["B3", "B5"]).rename("NDWI")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Compute the NDWI layers for the pre-flood and flood periods side by side.

# %%
m = geemap.Map()
ndwi_vis = {"min": -1, "max": 1, "palette": "ndwi"}
left_layer = geemap.ee_tile_layer(ndwi_pre, ndwi_vis, "NDWI Pre-flood")
right_layer = geemap.ee_tile_layer(ndwi_post, ndwi_vis, "NDWI Post-flood")
m.split_map(
    left_layer, right_layer, left_label="NDWI Pre-flood", right_label="NDWI Post-flood"
)
m.center_object(roi, 9)
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_49c80372403bbb7b526169ac29f8b9b1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/digidem/leaflet-side-by-side@2.0.0/leaflet-side-by-side.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_49c80372403bbb7b526169ac29f8b9b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_49c80372403bbb7b526169ac29f8b9b1 = L.map(
#                 &quot;map_49c80372403bbb7b526169ac29f8b9b1&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: false,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ca09b8cdd3f0790281c0ae1c1cd4576e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ca09b8cdd3f0790281c0ae1c1cd4576e.addTo(map_49c80372403bbb7b526169ac29f8b9b1);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_49c80372403bbb7b526169ac29f8b9b1);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_a8b7e496dbe725d9d57b1bf67601f581 = new L.featureGroup().addTo(
#                 map_49c80372403bbb7b526169ac29f8b9b1
#             );
#             options.edit.featureGroup = drawnItems_draw_control_a8b7e496dbe725d9d57b1bf67601f581;
#             var draw_control_a8b7e496dbe725d9d57b1bf67601f581 = new L.Control.Draw(
#                 options
#             ).addTo( map_49c80372403bbb7b526169ac29f8b9b1 );
#             map_49c80372403bbb7b526169ac29f8b9b1.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_a8b7e496dbe725d9d57b1bf67601f581.addLayer(layer);
#              });
#             map_49c80372403bbb7b526169ac29f8b9b1.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_a8b7e496dbe725d9d57b1bf67601f581.addLayer(e.layer);
#             });
#
#
#
#
#             var geocoderOpts_geocoder_e6908a7d08fbfd81e784f12f4791002b = {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_e6908a7d08fbfd81e784f12f4791002b = geocoderOpts_geocoder_e6908a7d08fbfd81e784f12f4791002b[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_e6908a7d08fbfd81e784f12f4791002b = L.Control.Geocoder[ geocoderName_geocoder_e6908a7d08fbfd81e784f12f4791002b ](
#                 geocoderOpts_geocoder_e6908a7d08fbfd81e784f12f4791002b[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_e6908a7d08fbfd81e784f12f4791002b[&quot;geocoder&quot;] = customGeocoder_geocoder_e6908a7d08fbfd81e784f12f4791002b;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_e6908a7d08fbfd81e784f12f4791002b
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_e6908a7d08fbfd81e784f12f4791002b[&#x27;zoom&#x27;] || map_49c80372403bbb7b526169ac29f8b9b1.getZoom();
#                 map_49c80372403bbb7b526169ac29f8b9b1.setView(e.geocode.center, zoom);
#             }).addTo(map_49c80372403bbb7b526169a

# %% [markdown]
# ## Extract Landsat water extent
#
# To extract the water extent, we need to convert the NDWI images to binary images using a threshold value. The threshold value is usually set to 0 to 0.3. The smaller the threshold value, the more water bodies will be detected, which may increase the false positive rate. The larger the threshold value, the fewer water bodies will be detected, which may increase the false negative rate.

# %%
threshold = -0.05
water_pre = ndwi_pre.gt(threshold)
water_post = ndwi_post.gt(threshold)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Combine the pre-flood and surface water extent side by side.

# %%
m = geemap.Map()

m.add_layer(pre_flood_image, vis_params, "Landsat Pre-flood", True)
m.add_layer(post_flood_image, vis_params, "Landsat Post-flood", True)

left_layer = geemap.ee_tile_layer(
    water_pre.selfMask(), {"palette": "blue"}, "Water Pre-flood"
)
right_layer = geemap.ee_tile_layer(
    water_post.selfMask(), {"palette": "red"}, "Water Post-flood"
)

m.split_map(
    left_layer,
    right_layer,
    left_label="Water Pre-flood",
    right_label="Water Post-flood",
)
m.center_object(roi, 9)
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74f99202ebf986adc6a4d6c0a267329e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/digidem/leaflet-side-by-side@2.0.0/leaflet-side-by-side.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74f99202ebf986adc6a4d6c0a267329e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_74f99202ebf986adc6a4d6c0a267329e = L.map(
#                 &quot;map_74f99202ebf986adc6a4d6c0a267329e&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: false,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6679067e869ce5fdc05d9069090586c8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6679067e869ce5fdc05d9069090586c8.addTo(map_74f99202ebf986adc6a4d6c0a267329e);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_74f99202ebf986adc6a4d6c0a267329e);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_fbd0f7165e6cc9cc615dfaf3df17cb6a = new L.featureGroup().addTo(
#                 map_74f99202ebf986adc6a4d6c0a267329e
#             );
#             options.edit.featureGroup = drawnItems_draw_control_fbd0f7165e6cc9cc615dfaf3df17cb6a;
#             var draw_control_fbd0f7165e6cc9cc615dfaf3df17cb6a = new L.Control.Draw(
#                 options
#             ).addTo( map_74f99202ebf986adc6a4d6c0a267329e );
#             map_74f99202ebf986adc6a4d6c0a267329e.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_fbd0f7165e6cc9cc615dfaf3df17cb6a.addLayer(layer);
#              });
#             map_74f99202ebf986adc6a4d6c0a267329e.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_fbd0f7165e6cc9cc615dfaf3df17cb6a.addLayer(e.layer);
#             });
#
#
#
#
#             var geocoderOpts_geocoder_a1832fe786fe0705150eb3792dbf4f1b = {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_a1832fe786fe0705150eb3792dbf4f1b = geocoderOpts_geocoder_a1832fe786fe0705150eb3792dbf4f1b[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_a1832fe786fe0705150eb3792dbf4f1b = L.Control.Geocoder[ geocoderName_geocoder_a1832fe786fe0705150eb3792dbf4f1b ](
#                 geocoderOpts_geocoder_a1832fe786fe0705150eb3792dbf4f1b[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_a1832fe786fe0705150eb3792dbf4f1b[&quot;geocoder&quot;] = customGeocoder_geocoder_a1832fe786fe0705150eb3792dbf4f1b;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_a1832fe786fe0705150eb3792dbf4f1b
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_a1832fe786fe0705150eb3792dbf4f1b[&#x27;zoom&#x27;] || map_74f99202ebf986adc6a4d6c0a267329e.getZoom();
#                 map_74f99202ebf986adc6a4d6c0a267329e.setView(e.geocode.center, zoom);
#             }).addTo(map_74f99202ebf986adc6a4d6c

# %% [markdown]
# ## Extract Landsat flood extent
#
# To extract the flood extent, we need to subtract the pre-flood water extent from the flood water extent. The flood extent is the difference between the flood water extent and the pre-flood water extent. In other words, pixels identified as water in the flood period but not in the pre-flood period are considered as flooded pixels. The `selfMask()` method is used to mask out the no-data pixels.

# %%
flood_extent = water_post.subtract(water_pre).gt(0).selfMask()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Add the flood extent layer to the map.

# %%
m = geemap.Map()

m.add_layer(pre_flood_image, vis_params, "Landsat Pre-flood", True)
m.add_layer(post_flood_image, vis_params, "Landsat Post-flood", True)

left_layer = geemap.ee_tile_layer(
    water_pre.selfMask(), {"palette": "blue"}, "Water Pre-flood"
)
right_layer = geemap.ee_tile_layer(
    water_post.selfMask(), {"palette": "red"}, "Water Post-flood"
)

m.split_map(
    left_layer,
    right_layer,
    left_label="Water Pre-flood",
    right_label="Water Post-flood",
)

m.add_layer(flood_extent, {"palette": "cyan"}, "Flood Extent")
m.center_object(roi, 9)
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e70bf29dedfd380b042afc8549c899ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/digidem/leaflet-side-by-side@2.0.0/leaflet-side-by-side.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e70bf29dedfd380b042afc8549c899ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e70bf29dedfd380b042afc8549c899ca = L.map(
#                 &quot;map_e70bf29dedfd380b042afc8549c899ca&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: false,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_529e405f79e69a0454221bdac2291456 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_529e405f79e69a0454221bdac2291456.addTo(map_e70bf29dedfd380b042afc8549c899ca);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_e70bf29dedfd380b042afc8549c899ca);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_1ad1128220fdce304cbcfba10d4dbae6 = new L.featureGroup().addTo(
#                 map_e70bf29dedfd380b042afc8549c899ca
#             );
#             options.edit.featureGroup = drawnItems_draw_control_1ad1128220fdce304cbcfba10d4dbae6;
#             var draw_control_1ad1128220fdce304cbcfba10d4dbae6 = new L.Control.Draw(
#                 options
#             ).addTo( map_e70bf29dedfd380b042afc8549c899ca );
#             map_e70bf29dedfd380b042afc8549c899ca.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_1ad1128220fdce304cbcfba10d4dbae6.addLayer(layer);
#              });
#             map_e70bf29dedfd380b042afc8549c899ca.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_1ad1128220fdce304cbcfba10d4dbae6.addLayer(e.layer);
#             });
#
#
#
#
#             var geocoderOpts_geocoder_a62139e872c0291b0fbc34418164cd82 = {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_a62139e872c0291b0fbc34418164cd82 = geocoderOpts_geocoder_a62139e872c0291b0fbc34418164cd82[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_a62139e872c0291b0fbc34418164cd82 = L.Control.Geocoder[ geocoderName_geocoder_a62139e872c0291b0fbc34418164cd82 ](
#                 geocoderOpts_geocoder_a62139e872c0291b0fbc34418164cd82[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_a62139e872c0291b0fbc34418164cd82[&quot;geocoder&quot;] = customGeocoder_geocoder_a62139e872c0291b0fbc34418164cd82;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_a62139e872c0291b0fbc34418164cd82
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_a62139e872c0291b0fbc34418164cd82[&#x27;zoom&#x27;] || map_e70bf29dedfd380b042afc8549c899ca.getZoom();
#                 map_e70bf29dedfd380b042afc8549c899ca.setView(e.geocode.center, zoom);
#             }).addTo(map_e70bf29dedfd380b042afc8

# %% [markdown]
# ## Calculate Landsat flood area
#
# To calculate the flood area, we can use the [`geemap.zonal_stats()`](https://geemap.org/common/#geemap.common.zonal_stats) function. The required input parameters are the flood extent layer and the country boundary layer. The `scale` parameter can be set to `30` to specify the spatial resolution of image to be used for calculating the zonal statistics. The `stats_type` parameter can be set to `SUM` to calculate the total area of the flood extent in square meters. Set `return_fc=True` to return the zonal statistics as an `ee.FeatureCollection` object, which can be converted to a Pandas dataframe.

# %%
area_pre_flood = geemap.zonal_stats(
    water_pre.selfMask(), roi, scale=30, stat_type="SUM", return_fc=True
)
area_pre_df = geemap.ee_to_df(area_pre_flood)
area_pre_df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Computing statistics ...
#             sum
# 0  1.357662e+06

# %%
print(f"Pre-flood water area: {round(area_pre_df['sum'].values[0] * 900 / 1e6)} km2")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Pre-flood water area: 1222 km2

# %%
area_post_flood = geemap.zonal_stats(
    water_post.selfMask(), roi, scale=30, stat_type="SUM", return_fc=True
)
area_post_df = geemap.ee_to_df(area_post_flood)
area_post_df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Computing statistics ...
#             sum
# 0  3.328183e+06

# %%
print(f"Post-flood water area: {round(area_post_df['sum'].values[0] * 900 / 1e6)} km2")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Post-flood water area: 2995 km2

# %%
flood_area = geemap.zonal_stats(
    flood_extent.selfMask(), roi, scale=30, stat_type="SUM", return_fc=True
)
flood_area_df = geemap.ee_to_df(flood_area)
flood_area_df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Computing statistics ...
#             sum
# 0  2.182365e+06

# %%
print(f"Flooded area: {round(flood_area_df['sum'].values[0] * 900 / 1e6)} km2")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Flooded area: 1964 km2

# %% [markdown]
# ## Create Sentinel-1 SAR composites
#
# Besides Landsat, we can also use Sentinel-1 [Synthetic Aperture Radar (SAR)](https://www.earthdata.nasa.gov/learn/backgrounders/what-is-sar) data to extract flood extent. Radar can collect signals in different polarizations, by controlling the analyzed polarization in both the transmit and receive paths. Signals emitted in vertical (V) and received in horizontal (H) polarization would be indicated by a VH. Alternatively, a signal that was emitted in horizontal (H) and received in horizontal (H) would be indicated by HH, and so on. Examining the signal strength from these different polarizations carries information about the structure of the imaged surface. Rough surface scattering, such as that caused by bare soil or water, is most sensitive to VV scattering. Therefore, VV polarization is often used to detect water bodies.
#
# Sentinel-1 operates in four exclusive [acquisition modes](https://sentinels.copernicus.eu/web/sentinel/missions/sentinel-1/instrument-payload):
#
# * Stripmap (SM)
# * Interferometric Wide swath (IW)
# * Extra-Wide swath (EW)
# * Wave mode (WV)
#
# The Interferometric Wide swath (IW) mode allows combining a large swath width (250 km) with a moderate geometric resolution (5 m by 20 m). The IW mode is the default acquisition mode over land. In this tutorial, we will use Sentinel-1 IW mode data to extract flood extent.
#
# The [Sentinel-1 SAR data](https://developers.google.com/earth-engine/datasets/catalog/COPERNICUS_S1_GRD) are available from 2014 to present. Let's filter the `COPERNICUS/S1_GRD` dataset by the date range and location.

# %%
pre_flood_start_date = "2024-06-01"
pre_flood_end_date = "2024-06-30"
post_flood_start_date = "2024-07-05"
post_flood_end_date = "2024-07-17"
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Create the Sentinel-1 image collection for the pre-flood period.

# %%
s1_col_pre = (
    ee.ImageCollection("COPERNICUS/S1_GRD")
    .filter(ee.Filter.listContains("transmitterReceiverPolarisation", "VV"))
    .filter(ee.Filter.eq("instrumentMode", "IW"))
    .filterDate(pre_flood_start_date, pre_flood_end_date)
    .filterBounds(roi)
    .select("VV")
)
print(
    f"The number of images in the pre-flood collection: {s1_col_pre.size().getInfo()}"
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# The number of images in the pre-flood collection: 4

# %% [markdown]
# Create the Sentinel-1 image collection for the post-flood period.

# %%
s1_col_post = (
    ee.ImageCollection("COPERNICUS/S1_GRD")
    .filter(ee.Filter.listContains("transmitterReceiverPolarisation", "VV"))
    .filter(ee.Filter.eq("instrumentMode", "IW"))
    # .filter(ee.Filter.eq('orbitProperties_pass', 'ASCENDING'))
    .filterDate(post_flood_start_date, post_flood_end_date)
    .filterBounds(roi)
    .select("VV")
)
print(
    f"The number of images in the post-flood collection: {s1_col_post.size().getInfo()}"
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# The number of images in the post-flood collection: 1

# %% [markdown]
# Create Sentinel-1 SAR composites for the pre- and post-flood periods.

# %%
m = geemap.Map()
m.add_basemap("Esri.WorldImagery")
sar_pre = s1_col_pre.reduce(ee.Reducer.percentile([20])).clipToCollection(roi)
sar_post = s1_col_post.reduce(ee.Reducer.percentile([20])).clipToCollection(roi)
m.add_layer(sar_pre, {"min": -25, "max": -5}, "SAR Pre-flood")
m.add_layer(sar_post, {"min": -25, "max": -5}, "SAR Post-flood")
m.center_object(roi, 9)
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b46e09aff061cf7081c4327eb886c6e0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b46e09aff061cf7081c4327eb886c6e0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b46e09aff061cf7081c4327eb886c6e0 = L.map(
#                 &quot;map_b46e09aff061cf7081c4327eb886c6e0&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: false,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_74b2781edcf25eb83198088cdb476f68 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_74b2781edcf25eb83198088cdb476f68.addTo(map_b46e09aff061cf7081c4327eb886c6e0);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_b46e09aff061cf7081c4327eb886c6e0);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_d4e8550c89c2217c3ccb8b03bc7c55a7 = new L.featureGroup().addTo(
#                 map_b46e09aff061cf7081c4327eb886c6e0
#             );
#             options.edit.featureGroup = drawnItems_draw_control_d4e8550c89c2217c3ccb8b03bc7c55a7;
#             var draw_control_d4e8550c89c2217c3ccb8b03bc7c55a7 = new L.Control.Draw(
#                 options
#             ).addTo( map_b46e09aff061cf7081c4327eb886c6e0 );
#             map_b46e09aff061cf7081c4327eb886c6e0.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_d4e8550c89c2217c3ccb8b03bc7c55a7.addLayer(layer);
#              });
#             map_b46e09aff061cf7081c4327eb886c6e0.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_d4e8550c89c2217c3ccb8b03bc7c55a7.addLayer(e.layer);
#             });
#
#
#
#
#             var geocoderOpts_geocoder_6fd1ca700ad4b5ed1b6459421bee08e8 = {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_6fd1ca700ad4b5ed1b6459421bee08e8 = geocoderOpts_geocoder_6fd1ca700ad4b5ed1b6459421bee08e8[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_6fd1ca700ad4b5ed1b6459421bee08e8 = L.Control.Geocoder[ geocoderName_geocoder_6fd1ca700ad4b5ed1b6459421bee08e8 ](
#                 geocoderOpts_geocoder_6fd1ca700ad4b5ed1b6459421bee08e8[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_6fd1ca700ad4b5ed1b6459421bee08e8[&quot;geocoder&quot;] = customGeocoder_geocoder_6fd1ca700ad4b5ed1b6459421bee08e8;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_6fd1ca700ad4b5ed1b6459421bee08e8
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_6fd1ca700ad4b5ed1b6459421bee08e8[&#x27;zoom&#x27;] || map_b46e09aff061cf7081c4327eb886c6e0.getZoom();
#                 map_b46e09aff061cf7081c4327eb886c6e0.setView(e.geocode.center, zoom);
#             }).addTo(map_b46e09aff061cf7081c4327eb886c6e0);
#
#
#
#             map_b46e09aff061cf7081c4327eb886c6e0.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&

# %% [markdown]
# ## Apply speckle filtering
#
# Speckle, appearing in synthetic aperture radar (SAR) images as granular noise, is due to the interference of waves reflected from many elementary scatterers. Speckle in SAR images complicates the image interpretation problem by reducing the effectiveness of image segmentation and classification ([Lee et al., 1994](https://doi.org/10.1080/02757259409532206)). Therefore, speckle filtering is often applied to SAR images to reduce the speckle noise. In this example, we apply a morphological speckle filter to the Sentinel-1 SAR images. The morphological speckle filter is a non-linear filter that uses the median value of a pixel and its neighboring pixels to replace the pixel value. The kernel size is set to 100 meters.

# %%
s1_col_pre = s1_col_pre.map(lambda img: img.focal_median(100, "circle", "meters"))
s1_col_post = s1_col_post.map(lambda img: img.focal_median(100, "circle", "meters"))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
m = geemap.Map()
m.add_basemap("Esri.WorldImagery")
sar_pre = s1_col_pre.reduce(ee.Reducer.percentile([20])).clipToCollection(roi)
sar_post = s1_col_post.reduce(ee.Reducer.percentile([20])).clipToCollection(roi)
m.add_layer(sar_pre, {"min": -25, "max": -5}, "SAR Pre-flood")
m.add_layer(sar_post, {"min": -25, "max": -5}, "SAR Post-flood")
m.center_object(roi, 9)
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1208ea1bbdc90b47b663514ad860b9b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1208ea1bbdc90b47b663514ad860b9b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1208ea1bbdc90b47b663514ad860b9b3 = L.map(
#                 &quot;map_1208ea1bbdc90b47b663514ad860b9b3&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: false,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1fde5c94e03bad2413545abd3f8067b3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1fde5c94e03bad2413545abd3f8067b3.addTo(map_1208ea1bbdc90b47b663514ad860b9b3);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_1208ea1bbdc90b47b663514ad860b9b3);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_cbcbe90cc19fd134ba34764829c266ae = new L.featureGroup().addTo(
#                 map_1208ea1bbdc90b47b663514ad860b9b3
#             );
#             options.edit.featureGroup = drawnItems_draw_control_cbcbe90cc19fd134ba34764829c266ae;
#             var draw_control_cbcbe90cc19fd134ba34764829c266ae = new L.Control.Draw(
#                 options
#             ).addTo( map_1208ea1bbdc90b47b663514ad860b9b3 );
#             map_1208ea1bbdc90b47b663514ad860b9b3.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_cbcbe90cc19fd134ba34764829c266ae.addLayer(layer);
#              });
#             map_1208ea1bbdc90b47b663514ad860b9b3.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_cbcbe90cc19fd134ba34764829c266ae.addLayer(e.layer);
#             });
#
#
#
#
#             var geocoderOpts_geocoder_9aec9beb53f34cd00d5f390a648131ab = {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_9aec9beb53f34cd00d5f390a648131ab = geocoderOpts_geocoder_9aec9beb53f34cd00d5f390a648131ab[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_9aec9beb53f34cd00d5f390a648131ab = L.Control.Geocoder[ geocoderName_geocoder_9aec9beb53f34cd00d5f390a648131ab ](
#                 geocoderOpts_geocoder_9aec9beb53f34cd00d5f390a648131ab[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_9aec9beb53f34cd00d5f390a648131ab[&quot;geocoder&quot;] = customGeocoder_geocoder_9aec9beb53f34cd00d5f390a648131ab;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_9aec9beb53f34cd00d5f390a648131ab
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_9aec9beb53f34cd00d5f390a648131ab[&#x27;zoom&#x27;] || map_1208ea1bbdc90b47b663514ad860b9b3.getZoom();
#                 map_1208ea1bbdc90b47b663514ad860b9b3.setView(e.geocode.center, zoom);
#             }).addTo(map_1208ea1bbdc90b47b663514ad860b9b3);
#
#
#
#             map_1208ea1bbdc90b47b663514ad860b9b3.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&

# %% [markdown]
# ## Compare Sentinel-1 SAR composites side by side
#
# Create a split-view map to compare the pre-flood and flood SAR composites side by side.

# %%
m = geemap.Map()
left_layer = geemap.ee_tile_layer(sar_pre, {"min": -25, "max": -5}, "SAR Pre-flood")
right_layer = geemap.ee_tile_layer(sar_post, {"min": -25, "max": -5}, "SAR Post-flood")

m.split_map(
    left_layer,
    right_layer,
    left_label="Sentinel-1 Pre-flood",
    right_label="Sentinel-1 Post_flood",
)
m.center_object(roi, 9)
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2bf161264c869aab3e0f3fa8488c9652 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/digidem/leaflet-side-by-side@2.0.0/leaflet-side-by-side.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2bf161264c869aab3e0f3fa8488c9652&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2bf161264c869aab3e0f3fa8488c9652 = L.map(
#                 &quot;map_2bf161264c869aab3e0f3fa8488c9652&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: false,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a8036c332a3d88ee8da988961cb72e6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7a8036c332a3d88ee8da988961cb72e6.addTo(map_2bf161264c869aab3e0f3fa8488c9652);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_2bf161264c869aab3e0f3fa8488c9652);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_9c8dfcd07c4ed63939c9aae4871e05fc = new L.featureGroup().addTo(
#                 map_2bf161264c869aab3e0f3fa8488c9652
#             );
#             options.edit.featureGroup = drawnItems_draw_control_9c8dfcd07c4ed63939c9aae4871e05fc;
#             var draw_control_9c8dfcd07c4ed63939c9aae4871e05fc = new L.Control.Draw(
#                 options
#             ).addTo( map_2bf161264c869aab3e0f3fa8488c9652 );
#             map_2bf161264c869aab3e0f3fa8488c9652.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_9c8dfcd07c4ed63939c9aae4871e05fc.addLayer(layer);
#              });
#             map_2bf161264c869aab3e0f3fa8488c9652.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_9c8dfcd07c4ed63939c9aae4871e05fc.addLayer(e.layer);
#             });
#
#
#
#
#             var geocoderOpts_geocoder_2f7da646a29188c09e3032921d0b6563 = {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_2f7da646a29188c09e3032921d0b6563 = geocoderOpts_geocoder_2f7da646a29188c09e3032921d0b6563[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_2f7da646a29188c09e3032921d0b6563 = L.Control.Geocoder[ geocoderName_geocoder_2f7da646a29188c09e3032921d0b6563 ](
#                 geocoderOpts_geocoder_2f7da646a29188c09e3032921d0b6563[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_2f7da646a29188c09e3032921d0b6563[&quot;geocoder&quot;] = customGeocoder_geocoder_2f7da646a29188c09e3032921d0b6563;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_2f7da646a29188c09e3032921d0b6563
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_2f7da646a29188c09e3032921d0b6563[&#x27;zoom&#x27;] || map_2bf161264c869aab3e0f3fa8488c9652.getZoom();
#                 map_2bf161264c869aab3e0f3fa8488c9652.setView(e.geocode.center, zoom);
#             }).addTo(map_2bf161264c869aab3e0f3fa

# %% [markdown]
# ## Extract SAR water extent
#
# Water usually appears dark in SAR images because radar waves are reflected differently by different surfaces. Water is a smooth, flat surface that does not reflect radar waves very well, so it appears dark in SAR images. Thresholding SAR imagery is one of the most widely used approaches to delineate water extent for its effectiveness and efficiency ([Liang and Liu, 2020](https://doi.org/10.1016/j.isprsjprs.2019.10.017)). Thresholding methods can be generally divided into two categories: global and local. Global thresholding methods use a single threshold value to segment the entire image. Local thresholding methods use a different threshold value for each pixel. In this example, we use a global thresholding method to extract the water extent. The threshold value is set to -16 dB.

# %%
threshold = -16
water_pre = sar_pre.lt(threshold)
water_post = sar_post.lt(threshold)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Create a split-view map to compare the pre-flood and flood water extent side by side.

# %%
m = geemap.Map()
m.add_layer(sar_pre, {"min": -25, "max": -5}, "SAR Pre-flood")
m.add_layer(sar_post, {"min": -25, "max": -5}, "SAR Post-flood")

left_layer = geemap.ee_tile_layer(
    water_pre.selfMask(), {"palette": "blue"}, "Water Pre-flood"
)
right_layer = geemap.ee_tile_layer(
    water_post.selfMask(), {"palette": "red"}, "Water Post-flood"
)

m.split_map(
    left_layer,
    right_layer,
    left_label="Water Pre-flood",
    right_label="Water Post-flood",
)
m.center_object(roi, 9)
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cc94aef5affdf2067db31c7fd7242798 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/digidem/leaflet-side-by-side@2.0.0/leaflet-side-by-side.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cc94aef5affdf2067db31c7fd7242798&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cc94aef5affdf2067db31c7fd7242798 = L.map(
#                 &quot;map_cc94aef5affdf2067db31c7fd7242798&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: false,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5614ec080dade4adb53e218cc3775e90 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5614ec080dade4adb53e218cc3775e90.addTo(map_cc94aef5affdf2067db31c7fd7242798);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_cc94aef5affdf2067db31c7fd7242798);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_542364aed54ce254991757de6df9adf5 = new L.featureGroup().addTo(
#                 map_cc94aef5affdf2067db31c7fd7242798
#             );
#             options.edit.featureGroup = drawnItems_draw_control_542364aed54ce254991757de6df9adf5;
#             var draw_control_542364aed54ce254991757de6df9adf5 = new L.Control.Draw(
#                 options
#             ).addTo( map_cc94aef5affdf2067db31c7fd7242798 );
#             map_cc94aef5affdf2067db31c7fd7242798.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_542364aed54ce254991757de6df9adf5.addLayer(layer);
#              });
#             map_cc94aef5affdf2067db31c7fd7242798.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_542364aed54ce254991757de6df9adf5.addLayer(e.layer);
#             });
#
#
#
#
#             var geocoderOpts_geocoder_f3153318c4720fa9477c0e20a3b1c82b = {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_f3153318c4720fa9477c0e20a3b1c82b = geocoderOpts_geocoder_f3153318c4720fa9477c0e20a3b1c82b[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_f3153318c4720fa9477c0e20a3b1c82b = L.Control.Geocoder[ geocoderName_geocoder_f3153318c4720fa9477c0e20a3b1c82b ](
#                 geocoderOpts_geocoder_f3153318c4720fa9477c0e20a3b1c82b[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_f3153318c4720fa9477c0e20a3b1c82b[&quot;geocoder&quot;] = customGeocoder_geocoder_f3153318c4720fa9477c0e20a3b1c82b;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_f3153318c4720fa9477c0e20a3b1c82b
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_f3153318c4720fa9477c0e20a3b1c82b[&#x27;zoom&#x27;] || map_cc94aef5affdf2067db31c7fd7242798.getZoom();
#                 map_cc94aef5affdf2067db31c7fd7242798.setView(e.geocode.center, zoom);
#             }).addTo(map_cc94aef5affdf2067db31c7

# %% [markdown]
# ## Extract SAR flood extent
#
# Similar to the Landsat approach, we can subtract the pre-flood water extent from the flood water extent to extract the flood extent.

# %%
flood_extent = water_post.subtract(water_pre).gt(0).selfMask()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# The flood extent is the difference between the flood water extent and the pre-flood water extent. In other words, pixels identified as water in the flood period but not in the pre-flood period are considered as flooded pixels, which are shown in cyan.

# %%
m = geemap.Map()

m.add_layer(sar_pre, {"min": -25, "max": -5}, "SAR Pre-flood")
m.add_layer(sar_post, {"min": -25, "max": -5}, "SAR Post-flood")

left_layer = geemap.ee_tile_layer(
    water_pre.selfMask(), {"palette": "blue"}, "Water Pre-flood"
)
right_layer = geemap.ee_tile_layer(
    water_post.selfMask(), {"palette": "red"}, "Water Post-flood"
)

m.split_map(
    left_layer,
    right_layer,
    left_label="Water Pre-flood",
    right_label="Water Post-flood",
)

m.add_layer(flood_extent, {"palette": "cyan"}, "Flood Extent")
m.center_object(roi, 9)
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eb4c36c5538d088f86bf04c62a0af439 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/digidem/leaflet-side-by-side@2.0.0/leaflet-side-by-side.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eb4c36c5538d088f86bf04c62a0af439&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eb4c36c5538d088f86bf04c62a0af439 = L.map(
#                 &quot;map_eb4c36c5538d088f86bf04c62a0af439&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: false,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9c053da2502390ff6339031b955d37fc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9c053da2502390ff6339031b955d37fc.addTo(map_eb4c36c5538d088f86bf04c62a0af439);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_eb4c36c5538d088f86bf04c62a0af439);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems_draw_control_f1b60b7cf171b7c5709e750abc0eb034 = new L.featureGroup().addTo(
#                 map_eb4c36c5538d088f86bf04c62a0af439
#             );
#             options.edit.featureGroup = drawnItems_draw_control_f1b60b7cf171b7c5709e750abc0eb034;
#             var draw_control_f1b60b7cf171b7c5709e750abc0eb034 = new L.Control.Draw(
#                 options
#             ).addTo( map_eb4c36c5538d088f86bf04c62a0af439 );
#             map_eb4c36c5538d088f86bf04c62a0af439.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_f1b60b7cf171b7c5709e750abc0eb034.addLayer(layer);
#              });
#             map_eb4c36c5538d088f86bf04c62a0af439.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_f1b60b7cf171b7c5709e750abc0eb034.addLayer(e.layer);
#             });
#
#
#
#
#             var geocoderOpts_geocoder_68b6cdf473df1c58b97177da9d7de588 = {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;, &quot;provider&quot;: &quot;nominatim&quot;, &quot;providerOptions&quot;: {}, &quot;zoom&quot;: 11};
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_68b6cdf473df1c58b97177da9d7de588 = geocoderOpts_geocoder_68b6cdf473df1c58b97177da9d7de588[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_68b6cdf473df1c58b97177da9d7de588 = L.Control.Geocoder[ geocoderName_geocoder_68b6cdf473df1c58b97177da9d7de588 ](
#                 geocoderOpts_geocoder_68b6cdf473df1c58b97177da9d7de588[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_68b6cdf473df1c58b97177da9d7de588[&quot;geocoder&quot;] = customGeocoder_geocoder_68b6cdf473df1c58b97177da9d7de588;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_68b6cdf473df1c58b97177da9d7de588
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_68b6cdf473df1c58b97177da9d7de588[&#x27;zoom&#x27;] || map_eb4c36c5538d088f86bf04c62a0af439.getZoom();
#                 map_eb4c36c5538d088f86bf04c62a0af439.setView(e.geocode.center, zoom);
#             }).addTo(map_eb4c36c5538d088f86bf04c

# %% [markdown]
# ## Calculate SAR flood area

# %%
area_pre_flood = geemap.zonal_stats(
    water_pre.selfMask(), roi, scale=30, stat_type="SUM", return_fc=True
)
area_pre_df = geemap.ee_to_df(area_pre_flood)
area_pre_df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Computing statistics ...
#             sum
# 0  2.333509e+06

# %%
print(f"Pre-flood water area: {round(area_pre_df['sum'].values[0] * 900 / 1e6)} km2")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Pre-flood water area: 2100 km2

# %%
area_post_flood = geemap.zonal_stats(
    water_post.selfMask(), roi, scale=30, stat_type="SUM", return_fc=True
)
area_post_df = geemap.ee_to_df(area_post_flood)
area_post_df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Computing statistics ...
#             sum
# 0  2.454894e+06

# %%
print(f"Post-flood water area: {round(area_post_df['sum'].values[0] * 900 / 1e6)} km2")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Post-flood water area: 2209 km2

# %%
flood_area = geemap.zonal_stats(
    flood_extent.selfMask(), roi, scale=30, stat_type="SUM", return_fc=True
)
flood_area_df = geemap.ee_to_df(flood_area)
flood_area_df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Computing statistics ...
#              sum
# 0  550634.537255

# %%
print(f"Flooded area: {round(flood_area_df['sum'].values[0] * 900 / 1e6)} km2")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Flooded area: 496 km2
